# %%
# %matplotlib notebook
import FunzioniBio

cromosoma = "cromosoma21"

FunzioniBio.mostra_alte_ripetizioni(cromosoma)
FunzioniBio.mostra_istogramma(cromosoma, 10, 7, 4.5, 150000)
# Out:
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
