# %%
# %matplotlib notebook
import FunzioniBio

cromosoma = "cromosoma18"

FunzioniBio.mostra_alte_ripetizioni(cromosoma, 2) #se il primo grafico esce vuoto incrementare il numero, aggiungere mbp alle x
FunzioniBio.mostra_istogramma(cromosoma, 10, 7, 5, 500000)
# Out:
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
