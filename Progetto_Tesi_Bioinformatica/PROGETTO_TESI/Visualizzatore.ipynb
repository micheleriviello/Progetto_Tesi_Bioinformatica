# %%
# %matplotlib notebook
import FunzioniBio

cromosoma = "cromosoma21"


FunzioniBio.mostra_alte_ripetizioni(cromosoma, 2) #se il primo grafico esce vuoto incrementare il numero
FunzioniBio.mostra_istogramma(cromosoma, 4, 7, 5, 10000000)
# Out:
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
